# %% [markdown]
# ## Setup

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib

# %%
import seaborn

# %% [markdown]
# ## Basic Data Structure

# %%
sr=pd.Series([1,3,5,7])
sr
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64

# %%
sr2=pd.Series([1,3,5,7],index=['A','B','C','D'])
sr2
# Out:
# A    1
# B    3
# C    5
# D    7
# dtype: int64

# %%
data={'ID':['1001','1002','1003','1004'],
    'Name':['Ann','Beth','Cathlyn','David'],
    'GPA':[3.51,2.75,3.04,2.24]}
df=pd.DataFrame(data)
df
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
data={'ID':['1001','1002','1003','1004'],
    'Name':['Ann','Beth','Cathlyn','David'],
    'GPA':[3.51,2.75,3.04,2.24]}
df2=pd.DataFrame(data,columns=['ID','Name','GPA'])
df2
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %% [markdown]
# ## Basic Input/Output

# %%
df2.to_csv('student.csv',index=False)

# %%
df3=pd.read_csv('student.csv')
df3
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
df4=pd.read_csv('student.csv', sep=',', header='infer', index_col='ID')
df4
# Out:
#          Name   GPA
# ID
# 1001      Ann  3.51
# 1002     Beth  2.75
# 1003  Cathlyn  3.04
# 1004    David  2.24

# %% [markdown]
# ## Directory Setup Commands

# %%
import os
os.chdir('/Users/krittitee/ComPro_2')
os.getcwd()
# Out:
# '/Users/krittitee/ComPro_2'

# %% [markdown]
# ## Basic Information

# %%
df3.shape
# Out:
# (4, 3)

# %%
df3.columns
# Out:
# Index(['ID', 'Name', 'GPA'], dtype='object')

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df3.dtypes
# Out:
# ID        int64
# Name     object
# GPA     float64
# dtype: object

# %%
df3.head()
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
sr.shape
# Out:
# (4,)

# %%
sr.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ## Basic Indexing

# %%
df3['Name']
# Out:
# 0        Ann
# 1       Beth
# 2    Cathlyn
# 3      David
# Name: Name, dtype: object

# %%
df3[1:3]
# Out:
#      ID     Name   GPA
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04

# %%
df3[1:]
# Out:
#      ID     Name   GPA
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
df3[:2]
# Out:
#      ID  Name   GPA
# 0  1001   Ann  3.51
# 1  1002  Beth  2.75

# %% [markdown]
# ### Indexing by label

# %%
df.loc[2:3]
# Out:
#      ID     Name   GPA
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
df3.loc[2:3, 'Name']
# Out:
# 2    Cathlyn
# 3      David
# Name: Name, dtype: object

# %%
df3.loc[:, 'Name']
# Out:
# 0        Ann
# 1       Beth
# 2    Cathlyn
# 3      David
# Name: Name, dtype: object

# %%
df3.loc[[0,2],'Name':'GPA']
# Out:
#       Name   GPA
# 0      Ann  3.51
# 2  Cathlyn  3.04

# %%
df4.loc[1002:1003, 'Name']
# Out:
# ID
# 1002       Beth
# 1003    Cathlyn
# Name: Name, dtype: object

# %% [markdown]
# ### Indexing by integer

# %%
df4.iloc[2:4,0]
# Out:
# ID
# 1003    Cathlyn
# 1004      David
# Name: Name, dtype: object

# %%
df4.iloc[2:4, 0:1]
# Out:
#          Name
# ID
# 1003  Cathlyn
# 1004    David

# %%
df4.iloc[:3]
# Out:
#          Name   GPA
# ID
# 1001      Ann  3.51
# 1002     Beth  2.75
# 1003  Cathlyn  3.04

# %%
df3.iloc[[0,2],[0,2]]
# Out:
#      ID   GPA
# 0  1001  3.51
# 2  1003  3.04

# %% [markdown]
# ## Boolean Indexing

# %%
df3[df3.Name == 'Beth']
# Out:
#      ID  Name   GPA
# 1  1002  Beth  2.75

# %%
df3[df3.GPA>3]
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 2  1003  Cathlyn  3.04

# %%
df3[df3.GPA>3]['Name']
# Out:
# 0        Ann
# 2    Cathlyn
# Name: Name, dtype: object

# %%
df3[(df3.GPA>2.5)&(df3.GPA<3.5)]
# Out:
#      ID     Name   GPA
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04

# %%
df3[(df3.ID==1002)|(df3.GPA>3.0)]
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04

# %%
df3[df3.Name.isin(['Ann','David'])]
# Out:
#      ID   Name   GPA
# 0  1001    Ann  3.51
# 3  1004  David  2.24

# %% [markdown]
# ## Sorting

# %%
df3.sort_values(by='GPA',ascending=False,inplace=False)
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 2  1003  Cathlyn  3.04
# 1  1002     Beth  2.75
# 3  1004    David  2.24

# %%
df3
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
df5=df3.copy()
df5.sort_values(by='GPA',ascending=True,inplace=True)
df5
# Out:
#      ID     Name   GPA
# 3  1004    David  2.24
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 0  1001      Ann  3.51

# %%
df3
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24

# %%
df5.sort_index(axis=0,ascending=False)
# Out:
#      ID     Name   GPA
# 3  1004    David  2.24
# 2  1003  Cathlyn  3.04
# 1  1002     Beth  2.75
# 0  1001      Ann  3.51

# %%
df5.sort_index(axis=1)
# Out:
#     GPA    ID     Name
# 3  2.24  1004    David
# 1  2.75  1002     Beth
# 2  3.04  1003  Cathlyn
# 0  3.51  1001      Ann

# %% [markdown]
# ## Inserting

# %%
df3.loc[4]=['1005','David','2.32']
df3
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 1  1002     Beth  2.75
# 2  1003  Cathlyn  3.04
# 3  1004    David  2.24
# 4  1005    David  2.32

# %%
df3 = df3.assign(Gender=['F','F','F','M','M'])
df3
# Out:
#      ID     Name   GPA Gender
# 0  1001      Ann  3.51      F
# 1  1002     Beth  2.75      F
# 2  1003  Cathlyn  3.04      F
# 3  1004    David  2.24      M
# 4  1005    David  2.32      M

# %%
df3=df3.assign(Age=[22,20,19,22,21])
df3
# Out:
#      ID     Name   GPA Gender  Age
# 0  1001      Ann  3.51      F   22
# 1  1002     Beth  2.75      F   20
# 2  1003  Cathlyn  3.04      F   19
# 3  1004    David  2.24      M   22
# 4  1005    David  2.32      M   21

# %% [markdown]
# ## Dropping

# %%
df4 = df3.copy()
df4
# Out:
#      ID     Name   GPA Gender  Age
# 0  1001      Ann  3.51      F   22
# 1  1002     Beth  2.75      F   20
# 2  1003  Cathlyn  3.04      F   19
# 3  1004    David  2.24      M   22
# 4  1005    David  2.32      M   21

# %%
df4.drop([1,3],axis=0)
# Out:
#      ID     Name   GPA Gender  Age
# 0  1001      Ann  3.51      F   22
# 2  1003  Cathlyn  3.04      F   19
# 4  1005    David  2.32      M   21

# %%
df4
# Out:
#      ID     Name   GPA Gender  Age
# 0  1001      Ann  3.51      F   22
# 1  1002     Beth  2.75      F   20
# 2  1003  Cathlyn  3.04      F   19
# 3  1004    David  2.24      M   22
# 4  1005    David  2.32      M   21

# %%
df4.drop([1,3],axis=0,inplace=True)

# %%
df4
# Out:
#      ID     Name   GPA Gender  Age
# 0  1001      Ann  3.51      F   22
# 2  1003  Cathlyn  3.04      F   19
# 4  1005    David  2.32      M   21

# %%
df4.drop(['Gender','Age'],axis=1)
# Out:
#      ID     Name   GPA
# 0  1001      Ann  3.51
# 2  1003  Cathlyn  3.04
# 4  1005    David  2.32
