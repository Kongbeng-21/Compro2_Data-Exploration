# %%
import os
os.chdir('/Users/krittitee/Compro2_DataExploration/EDA Assignment')  
os.getcwd()
# Out:
# '/Users/krittitee/Compro2_DataExploration/EDA Assignment'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
df = pd.read_csv('movie_data_2025.csv')
df.head()
# Out:
#                      Title      Genre              Director    Year  Runtime  \
# 0  Guardians of the Galaxy     Action            James Gunn  2014.0    121.0
# 1               Prometheus  Adventure          Ridley Scott  2012.0    124.0
# 2                    Split     Horror    M. Night Shyamalan  2016.0    117.0
# 3                     Sing  Animation  Christophe Lourdelet  2016.0    108.0
# 4            Suicide Squad     Action            David Ayer  2016.0    123.0
#
#    Rating     Votes
# 0     8.1  757074.0
# 1     7.0  485820.0
# 2     7.3  157606.0
# 3     7.2   60545.0
# 4     6.2  393727.0

# %% [markdown]
# ## Check Data Size and Data Types

# %%
## Enter code below to check "size of each dimension" (or shape) of data frame
df.shape
# Out:
# (1000, 7)

# %%
## Enter code below to extract "size of column" from the code box above
df.shape[0]
# Out:
# 1000

# %%
## Enter code below to show number of rows in data frame
df.shape[1]
# Out:
# 7

# %%
## Enter code below to check data types of attributes
df.dtypes
# Out:
# Title        object
# Genre        object
# Director     object
# Year        float64
# Runtime     float64
# Rating      float64
# Votes       float64
# dtype: object

# %%
## Enter code below to list attributes (columns)
df.columns
# Out:
# Index(['Title', 'Genre', 'Director', 'Year', 'Runtime', 'Rating', 'Votes'], dtype='object')

# %% [markdown]
# ## Handle Missing Data

# %%
## Enter code below to construct heatmap that shows missing data in dataframe
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='viridis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Enter code below to list columns with missing data percent > 0%
null_percent = df.isnull().sum()/len(df)*100
null_percent
# Out:
# Title       0.0
# Genre       0.2
# Director    0.5
# Year        0.9
# Runtime     0.5
# Rating      4.0
# Votes       4.2
# dtype: float64

# %% [markdown]
# From the missing data percent above, which attribute has missing data percent > 0%
#
# Answer : Type your answer here

# %% [markdown]
# Type up your plan to handle missing data (answer for each attribute separately)
#
# ** DO NOT USE ONLY dropna() **
#
# Try to think which value should we use to replace missing data, for each attribute?
#
# Answer : Type your plan here

# %%
## Enter code below to handle missing data
## Feel free to use as many code blocks as you need.

# %%
## After handling the missing data
## Enter code below to show
## 1) heatmap and
## 2) missing data percent for all columns

# %%
## Enter code below to show the updated data size

# %% [markdown]
# ## Data Distributions / Histograms

# %%
## Enter code below to show data rows where Director attribute value is 'Christopher Nolan'

# %%
## Enter code below to show values from Genre data column

# %%
## Enter code below to show data types of attributes

# %% [markdown]
# Which attributes have numerical values?
#
# Answer: Type your answer here

# %% [markdown]
# Which attributes have numerical statistics data-types?
#
# Answer: Type your answer here

# %%
## Enter code below to plot histograms of all numerical attributes in 1 command

# %%
## Enter code below to plot "frequencies" histogram of Rating only

# %%
## Enter code below to plot "probabilities" histogram of Votes only

# %% [markdown]
# What are the patterns of Rating frequencies histogram ?
#
# Answer: Type your answer here

# %% [markdown]
# What are the patterns of Votes probabilities histogram ?
#
# Answer: Type your answer here

# %% [markdown]
# ## Data Distributions / Boxplots

# %%
## Enter code below to show unique values from Genre data column

# %%
## Enter code below to plot botplot of runtime for different Genres

# %% [markdown]
# Which genre has the longest runtime?
#
# Answer: Type your answer here.

# %%
## Enter code below to plot botplot of Rating for different genre

# %% [markdown]
# Which genre has the lowest Rating?
#
# Answer: Type your answer here.

# %%
## Enter code below to show unique values from Year data column

# %%
## Enter code below to create new dataframe, called new_df
## This new_df contains data with Year greater than 2010

# %%
## Enter code below to plot botplot of Runtime for different years, using new_df

# %% [markdown]
# From the resulting boxplot of new_df, what is the trend of runtime over the years?
#
# Answer : Type your answer here

# %% [markdown]
# <caption><u><b>Expected output</u></b><br></caption>
#
# ![picture](images/class2_assign.png)
#
# If you cannot see the image, click this link: https://drive.google.com/file/d/19zUAdZK83pOq_AZ-JTH_g36YWFFRM6lj/view?usp=drive_link

# %%
## Create new column called "Action" to the "original" dataframe
## Set value in this new column to 'Action' if Genre in that row is 'Action', and to 'Not Action' for other Genres.

## See image above for how the dataframe looks like after new column 'Action' is created
## Hint: function 'where' from numpy may be useful here.
##      https://numpy.org/doc/2.2/reference/generated/numpy.where.html
## Example: df[col] = numpy.where(...)
## Enter the code below

# %%
## Enter code below to plot botplot of Runtime based on data with year after 2012
## Use new 'Action' column for hue
## Feel free to use as many code blocks as you need.

# %% [markdown]
# <caption><u><b>Expected output</u></b><br></caption>
#
# ![picture](images/class2_assign2.png)
#
# If you cannot see the image, click this link: https://drive.google.com/file/d/1L03SsUgEj_qht4-72DYUJyRY7wHAHUdI/view?usp=drive_link

# %%
## Create new column called "Drama" to the "original" dataframe
## Set value in this new column to 'Drama' if Genre in that row is 'Drama', and to 'Not Drama' for other Genres.

## See image above for how the dataframe looks like after new column 'Drama' is created
## Hint: function 'where' from numpy may be useful here.

# %%
## Enter code below to plot botplot of Runtime based on data with year after 2012
## Use new 'Drama' column for hue

# %%
## Enter code below to plot botplot of Rating based on data with year after 2012
## Use new 'Action' column for hue

# %%
## Enter code below to plot botplot of Rating based on data with year after 2012
## Use new 'Drama' column for hue

# %% [markdown]
# Explain how runtimes and ratings of Action movies changed over years, compared to non-Action moviews
#
# Answer: Type your answer here

# %% [markdown]
# Explain how runtimes and ratings of Drama movies changed over years, compared to non-Drama moviews
#
# Answer: Type your answer here

# %% [markdown]
# ## Descriptive Statistics

# %%
## Enter code below to show the descriptive statistics, using original dataframe

# %%
## Enter code below to show average runtime for each genre, using original dataframe

# %%
## Enter code below to show average rating for each genre, using original dataframe

# %%
## Are there any possible outliers for Votes attribute
## Enter the code to show your work below

# %%
## Using 3 thesholds (IQR, SD, percentile), determine whether Votes have outliers or not based on each threshold
## Remove outliers based on each threshold and save the remaining data in the new dataframe one at a time
## Thus, after applying 3 thresholds, there should be 3 new dataframes are constructed.

## Enter the code below
## Feel free to use as many code blocks as you need.

# %%
## Enter code below to show the size of original dataframe
## Also show the size of 3 new dataframes are constructed after outliers are removed.

# %% [markdown]
# Question: From the sizes of 3 new dataframes, which threshold removes outliers the most ?
#
# Answer: Type your answer here

# %%
## Enter code below to create 3 boxplots for 3 new dataframes
## Feel free to use as many code blocks as you need.

# %% [markdown]
# ## Scatter Plots and Correlation

# %%
## Enter code below to show scatterplot matrix for attributes with numerical values from original dataframe

# %% [markdown]
# Explain relationship between Runtime and Rating
#
# Answer : Type your answer here

# %% [markdown]
# Explain relationship between Runtime anda Votes
#
# Answer : Type your answer here

# %%
## Enter code below to show scatterplot matrix for Rating and Runtime, using hue as Action

# %% [markdown]
# Explain whether relationship between Runtime and Rating is different for Action, and non-Action movies or not.
#
# Answer : Type your answer here

# %%
## Enter code below to construct heatmap with correlation coefficients between attributes with numerical values

# %%
## Enter code below to construct scatter plot between Votes and Rating, using hue as Action

# %%
## Enter code below to construct heatmap with correlation coefficients for Action movies only

# %%
## Enter code below to construct heatmap with correlation coefficients for non-Action movies only

# %% [markdown]
# Comparing correlation coefficient between these two heatmaps,
#
# Explain whether relationship between any attributes pairs is different for Action, and non-Action movies or not.
#
# Answer : Type your answer here

# %%
## Enter code below to construct scatter/bubble plot to show relationship between 4 attributes (Runtime, Rating, Votes, Action)
## Use marker size as Runtime and hue as Action,

# %% [markdown]
# From the scatter plot above,
# Explain what correlaton cofficient should be between Votes and Rating
#
# Answer : Type your answer here

# %% [markdown]
# From the scatter plot above,
#
# When runtime is large, Rating is expected to be small or large
#
# Answer : Type your answer here
