# %%
import os
os.chdir('???')
os.getcwd()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exercises : tip.csv

# %%
orig_df = pd.read_csv('tips.csv')
orig_df.head()

# %% [markdown]
# ### tip.csv : Data Dict
#
# The data show bill information of customers at one restaurant.
#
# A group of customers had meal at one table and paid for one bill per group/table.
#
# total_bill = total payment per bill (unit = US dollars)
#
# tip = how much the customer gave tip per bill (unit = US dollars)
#
# sex = gender of customer who paid the bill
#
# smoker = whether the table of customer(s) in smoking area or not
#
# day = day of week that customer(s) came at the restaurant
#
# time = meal of day that customer(s) had at the restaurant
#
# size = size of table (or number of seats per table) for this bill

# %% [markdown]
# #### Problem 1:
#
# Create a graph to compare portions of tip percents for different table sizes;
#
# The graph should show how much tips from each size, compared to all tips.
#
# Add needed graph components for completed graph

# %%
# Code for problem 1

# %% [markdown]
# #### Problem 2:
#
# Create a graph to show portions of bill counts for different days;
#
# The graph should focus on comparing bill counts day by day and showing which day has more or less bill counts.
#
# Add needed graph components for completed graph

# %%
# Code for problem 2

# %% [markdown]
# #### Problem 3:
#
# Create a graph to show changes of revenue  on different days of the week
#
# Hint: Which attribute should be used to compute revenue?
#
# Add needed graph components for completed graph

# %%
# Code for problem 3

# %% [markdown]
# #### Problem 4:
#
# Create a graph to compare tips that the restaurant received on different days of the week.  The graph should rank the day that the restaurant received the tips from maximum to minimum.
#
# Add needed graph components for completed graph

# %%
# Code for problem 4

# %% [markdown]
# #### Problem 5:
#
# Create a graph to show portions of total_bills in dollars for different days and gender;
#
# The sum of total_bills for each day should show how much it came from male or female in dollars.
#
# Add needed graph components for completed graph

# %%
# Code for problem 5

# %% [markdown]
# #### Problem 6:
#
# Create similar graph problem 5 but for each day, show percent of total_bills from male or female.

# %%
# Code for problem 6

# %% [markdown]
# ## Exercises : Datetime

# %%
orig_df = pd.read_csv('beach_weather_stations_partial.csv')
orig_df.head()

# %% [markdown]
# #### Problem 7:
#
# Create a graph to compare weekly Air Temperature measurements collecting for a year, starting from 1 June 2017
#
# Add needed graph components for completed graph

# %%
# Code for problem 7

# %% [markdown]
# #### Problem 8
#
# Create a graph to show changes of average monthly Humidity, collected at 'Oak Street Weather Station', between 2016-2019
#
# Add needed graph components for completed graph

# %%
# Code for problem 8
